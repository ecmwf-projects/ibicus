# %% [markdown]
# # Overview of the evaluation module
#
# The evaluation module provides a set of functionalities that can help you assess the performance of your bias correction method. Bias correction is prone to mis-use and requires careful evaluation, as demonstrated and argued in Maraun et al. 2017. In particular, the bias correction methods implemented in this package operate on a marginal level, that is they correct distribution of individual variables at individual locations. There is therefore only a subset of climate model biases that these debiasers will be able to correct. Biases in the temporal or spatial structure of climate models, or the feedbacks to large-scale weather patterns might not be well corrected.
#
# It is therefore important to evaluate not only marginal but also temporal, spatial and spatiotemporal properties of the bias corrected model to gain insight into which biases have been corrected, and which remain after debiasing that hint towards larger-scale issues with the climate model used.
#
# **There are three components to the evaluation module:**
# - **Testing assumptions of different debiasers**: Different debiasers rely on different assumptions - some are parametrics, others non-parametric, some bias correct each day of the year separately, others are applied to all days of the year in the same way. This components is meant to check some of these assumptions and help the user rule out the use of some debiasers that are not fit for purpose in this specific application.
# - **Evaluating the bias corrected model on a validation period**: In order to assess the performance of a bias correction method, the bias corrected model data should be compared to observational / reanalysis data. This component provides insight into the correction of marginal biases, as well as temporal, spatial and spatiotemporal metrics.
# - **Investigating whether the climate change trend is preserved**: Bias correction methods can significantly modify the trend projected in the climate model simulation (Switanek 2017). If the user does not consider the simulated trend to be credible, then modifying it can be a good thing to do. However, any trend modification should always be a concious and informed choice, and it the belief that a bias correction method will improve the trend should be justified. Otherwise, the trend modification through the application of a bias correction method should be considered an artifact. Therefore, this section assesses whether a certain method preserves the cliamte model trend or not. Some methods implemented in this package are explicitly trend preserving, for more details see the methodologies and descriptions of the individual debiasers.
#
# **This notebook demonstrates the evaluation of three debiasers, ISIMIP (Lange 2021), CDFt (Vrac 2017) and Quantile Delta Mapping (Cannon et al 2015) to the variables tas (daily mean 2m surface temperature, K) and pr (total daily precipitation flux, kg/m2/s). ISIMIP is additionally applied to tasmin (daily minimum 2m surface temperature, K) and tasmax (daily maximum 2m surface temperature, K)**

# %% [markdown]
# ## Set-up and data pre-processing
#
# This step requires you to have downloaded and preprocessed observational or reanalysis data (such as ERA5) as well as a historical, as well as a future simulation of a climate model. Necessary pre-processing steps include regridding the datasets to the same area and grid in space and time and conducted checks for corrupted or missing data. If you don't have testing data yet, you can either work with the testing data stored in FOLDER, or use the PREPROCESS_NOTEBOOK to download new testing data.

# %%
import sys
sys.path.append("../")  # path contains python_file.py

# %%
import numpy as np
import iris
import math

from scipy.stats import norm, laplace, gamma, beta

from PACKAGE_NAME.variables import *
from PACKAGE_NAME.utils import gen_PrecipitationHurdleModel, gen_PrecipitationGammaLeftCensoredModel

from PACKAGE_NAME.debias import ECDFM, ISIMIP, QuantileMapping, DeltaChange, CDFt
from PACKAGE_NAME.debias import QuantileDeltaMapping, ScaledDistributionMapping, LinearScaling

from PACKAGE_NAME.evaluate import assumptions, correlation, marginal, multivariate, trend
from PACKAGE_NAME.evaluate.metrics import *

# %%
def get_data(variable, path = "../../../../Desktop/ECMWF/testing_data/for_package/", split_ratio = 0.7036):
    
    data = np.load(f"{path}{variable}.npz", allow_pickle = True)
    
    cut_off = math.floor(data["obs"].shape[0]*split_ratio)
    
    obs = data["obs"][0:cut_off, :, :]
    obs_validate = data["obs"][cut_off+1:, :, :]
    cm_hist = data["cm_hist"][0:cut_off, :, :]
    cm_validate = data["cm_hist"][cut_off+1:, :, :]
    cm_future = data["cm_future"]
    time_obs = data["time_obs"][0:cut_off]
    time_obs_validate = data["time_obs"][cut_off+1:]
    time_cm_hist = data["time_cm_hist"][0:cut_off]
    time_cm_validate = data["time_cm_hist"][cut_off+1:]
    time_cm_future = data["time_cm_future"]
    
    return obs, obs_validate, cm_hist, cm_validate, cm_future, time_obs, time_obs_validate, time_cm_hist, time_cm_validate, time_cm_future

# %% [markdown]
# Initialize testing data and dates for tas and pr

# %%
tas_obs, tas_obs_validate, tas_cm_hist, tas_cm_validate, tas_cm_future, tas_time_obs, tas_time_obs_validate, tas_time_cm_hist, tas_time_cm_validate, tas_time_cm_future = get_data("tas")
tasmin_obs, tasmin_obs_validate, tasmin_cm_hist, tasmin_cm_validate, tasmin_cm_future, tasmin_time_obs, tasmin_time_obs_validate, tasmin_time_cm_hist, tasmin_time_cm_validate, tasmin_time_cm_future = get_data("tasmin")
tasmax_obs, tasmax_obs_validate, tasmax_cm_hist, tasmax_cm_validate, tasmax_cm_future, tasmax_time_obs, tasmax_time_obs_validate, tasmax_time_cm_hist, tasmax_time_cm_validate, tasmax_time_cm_future = get_data("tasmax")
pr_obs, pr_obs_validate, pr_cm_hist, pr_cm_validate, pr_cm_future, pr_time_obs, pr_time_obs_validate, pr_time_cm_hist, pr_time_cm_validate, pr_time_cm_future = get_data("pr")

# %%
tas_time_cm_validate
# Out:
# array([cftime.DatetimeProlepticGregorian(1997, 12, 31, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(1998, 1, 1, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(1998, 1, 2, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeProlepticGregorian(2005, 12, 29, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(2005, 12, 30, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(2005, 12, 31, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)

# %% [markdown]
# **Calculating tasmin and tasmax**: currently only ISIMIP covers tasmin and tasmax. It also does not bias correct these two variables directly, but rather bias corrects the variables tasrange and tasskew, where
#
# $$ tasrange = tasmax - tasmin $$
#
# and
#
# $$ tasskew = \frac{tas − tasmin}{tasrange} $$
#
# The utils function 'get_tasmin_tasmax' calculates tasmin and tasmax from tasrange and tasskew.

# %%
tasrange_obs, tasskew_obs = utils.get_tasrange_tasskew(tas = tas_obs, tasmin = tasmin_obs, tasmax = tasmax_obs)
tasrange_obs_validate, tasskew_obs_validate = utils.get_tasrange_tasskew(tas = tas_obs_validate, tasmin = tasmin_obs_validate, tasmax = tasmax_obs_validate)

tasrange_cm_hist, tasskew_cm_hist = utils.get_tasrange_tasskew(tas = tas_cm_hist, tasmin = tasmin_cm_hist, tasmax = tasmax_cm_hist)
tasrange_cm_validate, tasskew_cm_validate = utils.get_tasrange_tasskew(tas = tas_cm_validate, tasmin = tasmin_cm_validate, tasmax = tasmax_cm_validate)

tasrange_cm_future, tasskew_cm_future = utils.get_tasrange_tasskew(tas = tas_cm_future, tasmin = tasmin_cm_future, tasmax = tasmax_cm_future)

# %% [markdown]
# ## Part 1: Testing assumptions
#
# Different bias correction methods rely on different assumptions, as described above. A detailed overview of assumptions associated with a specific bias correction method can be found in the documentation of each debiaser. For the sake of demonstration, we investigate the goodness of fit in this notebook:
#
# For all parametric methods, distributions are fitted to the data. Default distributions for each variable are specified in the individual debiasers. We assess the following two components:
# - Is the fit of the default distribution 'good enough' or should a different distribution be used? (1)
# - Is there any seasonality in the data that should be accounted for, for example by applying a 'running window mode' (meaning that the bias correction is fitted separately for different parts of the year, i.e. windows)? (2)
#
# **To-do: write down for which methods this is relevant**

# %% [markdown]
# **Step 1: Calculating the AIC and plottinge the worst fit**
#
# The Akaike Information Criterion is a statistical method for comparative evaluation among time series models. The AIC balances model complexity with goodness of fit, with a lower AIC being better. The AIC is calculated as follows:
#
# $$ AIC = 2 \frac{k}{n} - 2 \frac{l}{n}$$
#
# whereby $l$ is the log likelihood function calculated in the following way:
#
# $$ l = - \frac{n}{2} (1+ \ln(2 \pi) + \ln (\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y_i})^2)) $$
#
# Just for the sake of demonstration, we test the fit of the normal and the beta distribution to the temperature data.

# %%
tas_obs_aic = assumptions.calculate_aic('tas', tas_obs_validate, scipy.stats.norm, scipy.stats.beta)
# Out:
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# The following boxplot shows the distribution of the AIC across locations for the normal (left) and the beta (right) distribution:

# %%
assumptions.plot_aic(variable = 'tas', aic_values = tas_obs_aic)
# Out:
# [Text(0.5, 1.0, 'Distribution of AIC values across locations \n Daily mean near-surface air temperature')]

# %%
tas_obs_worst_fit = assumptions.plot_fit_worst_aic(variable = 'tas', dataset = tas_obs,  
                                                   data_type = 'Observed', distribution = scipy.stats.beta,
                                                   nr_bins = 100, aic_values = tas_obs_aic)

# %% [markdown]
# Given the plot we see above, and the strong bi-modal distribution of the temperature data, we make the assumption that might be seasonal variation at play here. This can be further investigated by using the following function: it plots the time-series and autocorrelation function of the quantile residuals. It also plot a QQ plot of the normalized quantile residuals to get a picture of the goodness of fit for different quantiles.

# %%
tas_obs_plot_gof = assumptions.plot_quantile_residuals(variable = 'tas', dataset = tas_obs[:,0,0], data_type = 'observation data',
                                                      distribution = scipy.stats.norm)

# %% [markdown]
# **Conclusion:**
#
# Overall the distributions do not seem to fit the temperature data too well. This is due to the bi-modal distribution of temperature. Based on the quantile residuals, we conclude that there is a strong seasonality at play. One option to address this issue would be to build a statistical model that explicitely includes the season as covariate (FIND SOURCE). An alternative approach is taken, for example, in both the QDM as well as the ISIMIP debiasers - using a running mode, a different bias correction is implemented for each day / month (more details in debiaser documentation). This takes care of the seasonality.

# %% [markdown]
# ## Initializing and applying the debiasers
#
# The following section initializes and applies the debiasers ISIMIP, CDFt and Quantile Delta Mapping (QDM) to the chosen variables. For a more detailed explanaition of the bias correction methods we refer to the documentation, and for some examples on how to customize different debiasers, we refer to the notebook DEBIASER_KNOBS.

# %% [markdown]
# **ISIMIP**

# %%
tas_debiaser_ISIMIP = ISIMIP.from_variable(variable = 'tas')
tas_val_debiased_ISIMIP = tas_debiaser_ISIMIP.apply(tas_obs, tas_cm_hist, tas_cm_validate, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_validate, verbosity='ERRORS_ONLY')
tas_fut_debiased_ISIMIP = tas_debiaser_ISIMIP.apply(tas_obs, tas_cm_hist, tas_cm_future, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
# 100%|███████████████████████████████████████████| 225/225 [07:32<00:00,  2.01s/it]
# 100%|███████████████████████████████████████████| 225/225 [08:30<00:00,  2.27s/it]

# %%
pr_time_cm_validate
# Out:
# array([cftime.DatetimeProlepticGregorian(1997, 11, 26, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(1997, 11, 27, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(1997, 11, 28, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeProlepticGregorian(2005, 12, 29, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(2005, 12, 30, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeProlepticGregorian(2005, 12, 31, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)

# %%
pr_debiaser_ISIMIP = ISIMIP.from_variable(variable = 'pr')
pr_val_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(pr_obs, pr_cm_hist, pr_cm_validate, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_validate, verbosity='ERRORS_ONLY')
pr_fut_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(pr_obs, pr_cm_hist, pr_cm_future, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
#   4%|█▉                                          | 10/225 [00:17<06:26,  1.80s/it]/Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:2757: RuntimeWarning: divide by zero encountered in double_scalars
#   aest = (3-s + np.sqrt((s-3)**2 + 24*s)) / (12*s)
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:2756: RuntimeWarning: invalid value encountered in double_scalars
#   func = lambda a: np.log(a) - sc.digamma(a) - s
# /Users/fionaspuler/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:2756: RuntimeWarning: invalid value encountered in log
#   func = lambda a: np.log(a) - sc.digamma(a) - s
#   6%|██▌                                         | 13/225 [00:23<06:26,  1.82s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 pr_debiaser_ISIMIP = ISIMIP.from_variable(variable = 'pr')
# ----> 2 pr_val_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(pr_obs, pr_cm_hist, pr_cm_validate, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_validate, verbosity='ERRORS_ONLY')
#       3 pr_fut_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(pr_obs, pr_cm_hist, pr_cm_future, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_future, verbosity='ERRORS_ONLY')
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_debiaser.py:400, in Debiaser.apply(self, obs, cm_hist, cm_future, verbosity, **kwargs)
#     396 logging.info("----- Running debiasing for variable: %s -----" % self.variable)
#     398 obs, cm_hist, cm_future = self._check_inputs_and_convert_if_possible(obs, cm_hist, cm_future)
# --> 400 output = Debiaser.map_over_locations(
#     401     self.apply_location, output_size=cm_future.shape, obs=obs, cm_hist=cm_hist, cm_future=cm_future, **kwargs
#     402 )
#     404 self._check_output(output)
#     406 return output
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_debiaser.py:348, in Debiaser.map_over_locations(func, output_size, obs, cm_hist, cm_future, **kwargs)
#     346 output = np.empty(output_size, dtype=cm_future.dtype)
#     347 for i, j in tqdm(np.ndindex(obs.shape[1:]), total=np.prod(obs.shape[1:])):
# --> 348     output[:, i, j] = func(obs[:, i, j], cm_hist[:, i, j], cm_future[:, i, j], **kwargs)
#     349 return output
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_isimip.py:1109, in ISIMIP.apply_location(self, obs, cm_hist, cm_future, time_obs, time_cm_hist, time_cm_future)
#    1102         indices_window_cm_hist = self.running_window.get_indices_vals_in_window(
#    1103             days_of_year_cm_hist, window_center
#    1104         )
#    1105         indices_window_cm_future = self.running_window.get_indices_vals_in_window(
#    1106             days_of_year_cm_future, window_center
#    1107         )
# -> 1109         debiased_cm_future[indices_bias_corrected_values] = self._apply_on_window(
#    1110             obs_hist=obs[indices_window_obs],
#    1111             cm_hist=cm_hist[indices_window_cm_hist],
#    1112             cm_future=cm_future[indices_window_cm_future],
#    1113             years_obs_hist=years_obs[indices_window_obs],
#    1114             years_cm_hist=years_cm_hist[indices_window_cm_hist],
#    1115             years_cm_future=years_cm_future[indices_window_cm_future],
#    1116         )[np.in1d(indices_window_cm_future, indices_bias_corrected_values)]
#    1118 else:
#    1119     months_obs = month(time_obs)
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_isimip.py:1050, in ISIMIP._apply_on_window(self, obs_hist, cm_hist, cm_future, years_obs_hist, years_cm_hist, years_cm_future)
#    1048 obs_hist, cm_hist, cm_future = self.step4(obs_hist, cm_hist, cm_future)
#    1049 obs_future = self.step5(obs_hist, cm_hist, cm_future)
# -> 1050 cm_future = self.step6(obs_hist, obs_future, cm_hist, cm_future)
#    1051 cm_future = self.step7(cm_future, trend_cm_future)
#    1052 # Step 1 & 8 are outside the running window iteration
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_isimip.py:996, in ISIMIP.step6(self, obs_hist, obs_future, cm_hist, cm_future)
#     994 # Calculate values between bounds (if any are to be calculated)
#     995 if any(mask_for_entries_not_set_to_either_bound):
# --> 996     mapped_vals[mask_for_entries_not_set_to_either_bound] = self._step6_adjust_values_between_thresholds(
#     997         self._get_values_between_thresholds(obs_hist_sorted),
#     998         self._get_values_between_thresholds(obs_future_sorted),
#     999         self._get_values_between_thresholds(cm_hist_sorted),
#    1000         mapped_vals[mask_for_entries_not_set_to_either_bound],
#    1001         self._get_values_between_thresholds(cm_future_sorted),
#    1002     )
#    1004 # Return values inserted back at correct locations
#    1005 reverse_sorting_idx = np.argsort(cm_future_argsort)
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_isimip.py:708, in ISIMIP._step6_adjust_values_between_thresholds(self, obs_hist_sorted_entries_between_thresholds, obs_future_sorted_entries_between_thresholds, cm_hist_sorted_entries_between_thresholds, cm_future_sorted_entries_not_sent_to_bound, cm_future_sorted_entries_between_thresholds)
#     697 def _step6_adjust_values_between_thresholds(
#     698     self,
#     699     obs_hist_sorted_entries_between_thresholds,
#    (...)
#     705
#     706     # ISIMIP v2.5: entries between bounds are mapped non-parametically on entries between thresholds (previous to bound adjustment)
#     707     if self.has_threshold and not self.nonparametric_qm:
# --> 708         cm_future_sorted_entries_not_sent_to_bound = quantile_map_x_on_y_non_parametically(
#     709             x=cm_future_sorted_entries_not_sent_to_bound,
#     710             y=cm_future_sorted_entries_between_thresholds,
#     711             mode=self.mode_non_parametric_qm,
#     712             ecdf_method=self.ecdf_method,
#     713             iecdf_method=self.iecdf_method,
#     714         )
#     716     if self.nonparametric_qm:
#     717         return quantile_map_non_parametically(
#     718             x=cm_future_sorted_entries_not_sent_to_bound,
#     719             y=obs_future_sorted_entries_between_thresholds,
#    (...)
#     722             iecdf_method=self.iecdf_method,
#     723         )
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/utils/_math_utils.py:660, in quantile_map_x_on_y_non_parametically(x, y, mode, ecdf_method, iecdf_method, **kwargs)
#     656     return quantile_map_non_parametically(
#     657         x=x, y=y, vals=x, ecdf_method=ecdf_method, iecdf_method=iecdf_method, **kwargs
#     658     )
#     659 elif mode == "isimipv3.0":
# --> 660     return _isimip_quantile_map_x_on_y_non_parametically(x, y)
#     661 else:
#     662     raise ValueError('mode needs to be one of ["normal", "isimipv3.0"]')
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/utils/_math_utils.py:622, in _isimip_quantile_map_x_on_y_non_parametically(x, y)
#     620 p_x = (scipy.stats.rankdata(x) - 1.0) / x.size
#     621 p_y = np.linspace(0.0, 1.0, y.size, dtype=y.dtype)
# --> 622 z = np.interp(p_x, p_y, np.sort(y)).astype(y.dtype)
#     623 return z
#
# File <__array_function__ internals>:180, in interp(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:1570, in interp(x, xp, fp, left, right, period)
#    1567     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1568     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1570 return interp_func(x, xp, fp, left, right)
#
# ValueError: array of sample points is empty

# %%
tasrange_debiaser_ISIMIP = ISIMIP.from_variable(variable = 'tasrange')
tasrange_val_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(tasrange_obs, tasrange_cm_hist, tasrange_cm_validate, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_validate, verbosity='ERRORS_ONLY')
tasrange_fut_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(tasrange_obs, tasrange_cm_hist, tasrange_cm_future, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
# 100%|███████████████████████████████████████████| 225/225 [05:44<00:00,  1.53s/it]
# 100%|███████████████████████████████████████████| 225/225 [07:13<00:00,  1.93s/it]

# %%
tasskew_debiaser_ISIMIP = ISIMIP.from_variable(variable = 'tasrange')
tasskew_val_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(tasskew_obs, tasskew_cm_hist, tasskew_cm_validate, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_validate, verbosity='ERRORS_ONLY')
tasskew_fut_debiased_ISIMIP = pr_debiaser_ISIMIP.apply(tasskew_obs, tasskew_cm_hist, tasskew_cm_future, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
# 100%|███████████████████████████████████████████| 225/225 [01:10<00:00,  3.19it/s]
# 100%|███████████████████████████████████████████| 225/225 [01:36<00:00,  2.33it/s]

# %%
tasmin_val_debiased_ISIMIP, tasmax_val_debiased_ISIMIP = utils.get_tasmin_tasmax(tas = tas_val_debiased_ISIMIP, tasrange = tasrange_val_debiased_ISIMIP, tasskew = tasskew_val_debiased_ISIMIP)
tasmin_fut_debiased_ISIMIP, tasmax_fut_debiased_ISIMIP = utils.get_tasmin_tasmax(tas = tas_fut_debiased_ISIMIP, tasrange = tasrange_fut_debiased_ISIMIP, tasskew = tasskew_fut_debiased_ISIMIP)

# %% [markdown]
# **CDFt**

# %%
tas_debiaser_CDFT = CDFt.from_variable(variable = 'tas')
tas_val_debiased_CDFT = tas_debiaser_CDFT.apply(tas_obs, tas_cm_hist, tas_cm_validate, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_validate, verbosity='ERRORS_ONLY')
tas_fut_debiased_CDFT = tas_debiaser_CDFT.apply(tas_obs, tas_cm_hist, tas_cm_future, time_obs = tas_time_obs, time_cm_hist = tas_time_cm_hist, time_cm_future = tas_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
# 100%|███████████████████████████████████████████| 225/225 [00:10<00:00, 21.79it/s]
# 100%|███████████████████████████████████████████| 225/225 [00:34<00:00,  6.51it/s]

# %%
pr_debiaser_CDFT = CDFt.from_variable(variable = 'pr')
pr_val_debiased_CDFT = pr_debiaser_CDFT.apply(pr_obs, pr_cm_hist, pr_cm_validate, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_validate, verbosity='ERRORS_ONLY')
pr_fut_debiased_CDFT = pr_debiaser_CDFT.apply(pr_obs, pr_cm_hist, pr_cm_future, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
# 100%|███████████████████████████████████████████| 225/225 [00:09<00:00, 23.22it/s]
# 100%|███████████████████████████████████████████| 225/225 [00:32<00:00,  6.90it/s]

# %% [markdown]
# **Quantile Delta Mapping**

# %%
tas_debiaser_QDM = QuantileDeltaMapping.from_variable(variable = "tas")
#tas_val_debiased_QDM = tas_debiaser_QDM.apply(tas_obs, tas_cm_hist, tas_cm_validate, verbosity='INFO')
tas_fut_debiased_QDM = tas_debiaser_QDM.apply(tas_obs, tas_cm_hist, tas_cm_future, verbosity='INFO')
# Out:
# INFO:root:----- Running debiasing for variable: Daily mean near-surface air temperature -----
#   0%|                                                     | 0/225 [00:00<?, ?it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   0%|▏                                            | 1/225 [00:01<03:59,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   1%|▍                                            | 2/225 [00:02<03:52,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   1%|▌                                            | 3/225 [00:03<03:56,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   2%|▊                                            | 4/225 [00:04<03:57,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   2%|█                                            | 5/225 [00:05<03:54,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   3%|█▏                                           | 6/225 [00:06<03:50,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   3%|█▍                                           | 7/225 [00:07<03:50,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   4%|█▌                                           | 8/225 [00:08<03:49,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   4%|█▊                                           | 9/225 [00:09<03:46,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   4%|█▉                                          | 10/225 [00:10<03:42,  1.03s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   5%|██▏                                         | 11/225 [00:11<03:39,  1.03s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   5%|██▎                                         | 12/225 [00:12<03:41,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   6%|██▌                                         | 13/225 [00:13<03:38,  1.03s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   6%|██▋                                         | 14/225 [00:14<03:33,  1.01s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#   7%|██▉                                         | 15/225 [00:15<03:30,  1.00s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   7%|███▏                                        | 16/225 [00:16<03:32,  1.02s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   8%|███▎                                        | 17/225 [00:17<03:35,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   8%|███▌                                        | 18/225 [00:18<03:37,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   8%|███▋                                        | 19/225 [00:19<03:36,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   9%|███▉                                        | 20/225 [00:20<03:34,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#   9%|████                                        | 21/225 [00:21<03:34,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  10%|████▎                                       | 22/225 [00:22<03:35,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  10%|████▍                                       | 23/225 [00:24<03:35,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  11%|████▋                                       | 24/225 [00:25<03:38,  1.09s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  11%|████▉                                       | 25/225 [00:26<03:42,  1.11s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  12%|█████                                       | 26/225 [00:27<03:41,  1.12s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  12%|█████▎                                      | 27/225 [00:28<03:41,  1.12s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  12%|█████▍                                      | 28/225 [00:29<03:39,  1.11s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  13%|█████▋                                      | 29/225 [00:30<03:37,  1.11s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#  13%|█████▊                                      | 30/225 [00:31<03:35,  1.11s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  14%|██████                                      | 31/225 [00:33<03:35,  1.11s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  14%|██████▎                                     | 32/225 [00:34<03:31,  1.09s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  15%|██████▍                                     | 33/225 [00:35<03:27,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  15%|██████▋                                     | 34/225 [00:36<03:24,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  16%|██████▊                                     | 35/225 [00:37<03:23,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  16%|███████                                     | 36/225 [00:38<03:22,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  16%|███████▏                                    | 37/225 [00:39<03:18,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  17%|███████▍                                    | 38/225 [00:40<03:13,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  17%|███████▋                                    | 39/225 [00:41<03:12,  1.03s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  18%|███████▊                                    | 40/225 [00:42<03:12,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  18%|████████                                    | 41/225 [00:43<03:09,  1.03s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  19%|████████▏                                   | 42/225 [00:44<03:05,  1.02s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  19%|████████▍                                   | 43/225 [00:45<03:02,  1.00s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  20%|████████▌                                   | 44/225 [00:46<03:00,  1.01it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#  20%|████████▊                                   | 45/225 [00:47<02:57,  1.01it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  20%|████████▉                                   | 46/225 [00:48<02:56,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  21%|█████████▏                                  | 47/225 [00:49<02:59,  1.01s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  21%|█████████▍                                  | 48/225 [00:50<03:00,  1.02s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  22%|█████████▌                                  | 49/225 [00:51<03:03,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  22%|█████████▊                                  | 50/225 [00:52<03:03,  1.05s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  23%|█████████▉                                  | 51/225 [00:53<03:03,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  23%|██████████▏                                 | 52/225 [00:54<03:03,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  24%|██████████▎                                 | 53/225 [00:55<03:02,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  24%|██████████▌                                 | 54/225 [00:56<03:02,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  24%|██████████▊                                 | 55/225 [00:57<03:02,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  25%|██████████▉                                 | 56/225 [00:59<03:01,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  25%|███████████▏                                | 57/225 [01:00<03:01,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  26%|███████████▎                                | 58/225 [01:01<03:00,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  26%|███████████▌                                | 59/225 [01:02<03:00,  1.09s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#  27%|███████████▋                                | 60/225 [01:03<02:57,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  27%|███████████▉                                | 61/225 [01:04<02:55,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  28%|████████████                                | 62/225 [01:05<02:54,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  28%|████████████▎                               | 63/225 [01:06<02:52,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  28%|████████████▌                               | 64/225 [01:07<02:52,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  29%|████████████▋                               | 65/225 [01:08<02:51,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  29%|████████████▉                               | 66/225 [01:09<02:51,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  30%|█████████████                               | 67/225 [01:10<02:48,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  30%|█████████████▎                              | 68/225 [01:11<02:47,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  31%|█████████████▍                              | 69/225 [01:13<02:47,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  31%|█████████████▋                              | 70/225 [01:14<02:46,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  32%|█████████████▉                              | 71/225 [01:15<02:45,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  32%|██████████████                              | 72/225 [01:16<02:44,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  32%|██████████████▎                             | 73/225 [01:17<02:46,  1.09s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  33%|██████████████▍                             | 74/225 [01:18<02:42,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#  33%|██████████████▋                             | 75/225 [01:19<02:40,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  34%|██████████████▊                             | 76/225 [01:20<02:39,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  34%|███████████████                             | 77/225 [01:21<02:39,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  35%|███████████████▎                            | 78/225 [01:22<02:36,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  35%|███████████████▍                            | 79/225 [01:23<02:36,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  36%|███████████████▋                            | 80/225 [01:24<02:35,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  36%|███████████████▊                            | 81/225 [01:25<02:35,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  36%|████████████████                            | 82/225 [01:27<02:34,  1.08s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  37%|████████████████▏                           | 83/225 [01:28<02:31,  1.07s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  37%|████████████████▍                           | 84/225 [01:29<02:29,  1.06s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  38%|████████████████▌                           | 85/225 [01:30<02:25,  1.04s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
# ...
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  88%|█████████████████████████████████████▋     | 197/225 [03:27<00:27,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  88%|█████████████████████████████████████▊     | 198/225 [03:28<00:26,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  88%|██████████████████████████████████████     | 199/225 [03:29<00:25,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  89%|██████████████████████████████████████▏    | 200/225 [03:30<00:24,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  89%|██████████████████████████████████████▍    | 201/225 [03:31<00:23,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  90%|██████████████████████████████████████▌    | 202/225 [03:32<00:22,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  90%|██████████████████████████████████████▊    | 203/225 [03:33<00:21,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  91%|██████████████████████████████████████▉    | 204/225 [03:34<00:20,  1.01it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  91%|███████████████████████████████████████▏   | 205/225 [03:35<00:19,  1.01it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  92%|███████████████████████████████████████▎   | 206/225 [03:36<00:19,  1.00s/it]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  92%|███████████████████████████████████████▌   | 207/225 [03:37<00:17,  1.01it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  92%|███████████████████████████████████████▊   | 208/225 [03:38<00:16,  1.01it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  93%|███████████████████████████████████████▉   | 209/225 [03:39<00:15,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#  93%|████████████████████████████████████████▏  | 210/225 [03:40<00:14,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  94%|████████████████████████████████████████▎  | 211/225 [03:41<00:13,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  94%|████████████████████████████████████████▌  | 212/225 [03:42<00:12,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  95%|████████████████████████████████████████▋  | 213/225 [03:43<00:11,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  95%|████████████████████████████████████████▉  | 214/225 [03:44<00:10,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  96%|█████████████████████████████████████████  | 215/225 [03:44<00:09,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  96%|█████████████████████████████████████████▎ | 216/225 [03:45<00:08,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  96%|█████████████████████████████████████████▍ | 217/225 [03:46<00:07,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  97%|█████████████████████████████████████████▋ | 218/225 [03:47<00:06,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  97%|█████████████████████████████████████████▊ | 219/225 [03:48<00:05,  1.02it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  98%|██████████████████████████████████████████ | 220/225 [03:49<00:04,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  98%|██████████████████████████████████████████▏| 221/225 [03:50<00:03,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  99%|██████████████████████████████████████████▍| 222/225 [03:51<00:02,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
#  99%|██████████████████████████████████████████▌| 223/225 [03:52<00:01,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
#
# 100%|██████████████████████████████████████████▊| 224/225 [03:53<00:00,  1.03it/s]WARNING:root:
#                     QuantileDeltaMapping runs without time-information for at least one of obs, cm_hist or cm_future.
#                     This information is inferred, assuming the first observation is on a January 1st. Observations are chunked according to the assumed time information.
#                     This might lead to slight numerical differences to the run with time information, however the debiasing is not fundamentally changed.
# 100%|███████████████████████████████████████████| 225/225 [03:54<00:00,  1.04s/it]

# %%
pr_debiaser_QDM = QuantileDeltaMapping.from_variable(variable = "pr")
pr_val_debiased_QDM = pr_debiaser_QDM.apply(pr_obs, pr_cm_hist, pr_cm_validate, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_validate, verbosity='ERRORS_ONLY')
pr_fut_debiased_QDM = pr_debiaser_QDM.apply(pr_obs, pr_cm_hist, pr_cm_future, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_future, verbosity='ERRORS_ONLY')
# Out:
#   0%|                                                     | 0/225 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 pr_debiaser_QDM = QuantileDeltaMapping.from_variable(variable = "pr")
# ----> 2 pr_val_debiased_QDM = pr_debiaser_QDM.apply(pr_obs, pr_cm_hist, pr_cm_validate, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_validate, verbosity='ERRORS_ONLY')
#       3 pr_fut_debiased_QDM = pr_debiaser_QDM.apply(pr_obs, pr_cm_hist, pr_cm_future, time_obs = pr_time_obs, time_cm_hist = pr_time_cm_hist, time_cm_future = pr_time_cm_future, verbosity='ERRORS_ONLY')
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_debiaser.py:400, in Debiaser.apply(self, obs, cm_hist, cm_future, verbosity, **kwargs)
#     396 logging.info("----- Running debiasing for variable: %s -----" % self.variable)
#     398 obs, cm_hist, cm_future = self._check_inputs_and_convert_if_possible(obs, cm_hist, cm_future)
# --> 400 output = Debiaser.map_over_locations(
#     401     self.apply_location, output_size=cm_future.shape, obs=obs, cm_hist=cm_hist, cm_future=cm_future, **kwargs
#     402 )
#     404 self._check_output(output)
#     406 return output
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_debiaser.py:348, in Debiaser.map_over_locations(func, output_size, obs, cm_hist, cm_future, **kwargs)
#     346 output = np.empty(output_size, dtype=cm_future.dtype)
#     347 for i, j in tqdm(np.ndindex(obs.shape[1:]), total=np.prod(obs.shape[1:])):
# --> 348     output[:, i, j] = func(obs[:, i, j], cm_hist[:, i, j], cm_future[:, i, j], **kwargs)
#     349 return output
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/debias/_quantile_delta_mapping.py:360, in QuantileDeltaMapping.apply_location(self, obs, cm_hist, cm_future, time_obs, time_cm_hist, time_cm_future)
#     353         indices_window_cm_hist = self.running_window_within_year.get_indices_vals_in_window(
#     354             days_of_year_cm_hist, window_center
#     355         )
#     356         indices_window_cm_future = self.running_window_within_year.get_indices_vals_in_window(
#     357             days_of_year_cm_future, window_center
#     358         )
# --> 360         debiased_cm_future[indices_bias_corrected_values] = self._apply_on_within_year_window(
#     361             obs=obs[indices_window_obs],
#     362             cm_hist=cm_hist[indices_window_cm_hist],
#     363             cm_future=cm_future[indices_window_cm_future],
#     364             years_cm_future=years_cm_future[indices_window_cm_future],
#     365         )[np.in1d(indices_window_cm_future, indices_bias_corrected_values)]
#     367     return debiased_cm_future
#     369 else:
#
# ValueError: shape mismatch: value array of shape (291,) could not be broadcast to indexing result of shape (245,)

# %%
tas_debiaser_QM = QuantileMapping.from_variable(variable = "tas")
tas_val_debiased_QM = tas_debiaser_QM.apply(tas_obs, tas_cm_hist, tas_cm_validate, verbosity='ERRORS_ONLY')
tas_fut_debiased_QM = tas_debiaser_QM.apply(tas_obs, tas_cm_hist, tas_cm_future, verbosity='ERRORS_ONLY')

pr_debiaser_QM = QuantileMapping.from_variable(variable = "pr")
pr_val_debiased_QM = pr_debiaser_QM.apply(pr_obs, pr_cm_hist, pr_cm_validate, verbosity='ERRORS_ONLY')
pr_fut_debiased_QM = pr_debiaser_QM.apply(pr_obs, pr_cm_hist, pr_cm_future, verbosity='ERRORS_ONLY')
# Out:
# 100%|█████████████████████████████████████████| 225/225 [00:00<00:00, 1203.74it/s]
# 100%|██████████████████████████████████████████| 225/225 [00:00<00:00, 873.96it/s]
# 100%|██████████████████████████████████████████| 225/225 [00:01<00:00, 221.87it/s]
# 100%|███████████████████████████████████████████| 225/225 [00:02<00:00, 97.61it/s]

# %% [markdown]
# ## Part 2: Evaluation on validation dataset

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# ### Overview: Statistical Properties and Threshold Metrics
#
# There are essentially two types of analysis that the evaluation module enables you to conduct: one ist an analysis of the statistical properties of the debiased variable - this includes the marginal bias of descriptive statistics such as the mean, or 5th and 95th percentile, as well as the difference in spatial correlation structure. The other is an analysis of threshold metrics. What we mean by the term threshold metrics here, is that specific thresholds are often relevent for impact studies and other applications - for example the number of frost days for crop modelling. Here we can analyse not only the marginal bias, but also the spell length of days of threshold exceedance, or their spatial extent and spatiotemporal cluster size.
#
# The following table gives an overview, which types of analysis are currently available in this release of the package.
#
#
#
# |                  | Statistical Properties | Threshold Metrics  |
# | ------------     | ---------------------- | -----------------  |
# | **Marginal**     | x - marginal bias      | x - marginal bias  |
# | **Temporal**     |                        | x - spell length   |
# | **Spatial**      | x - RMSE corr matrices | x - spatial extent |
# | **Spatioteporal**|                        | x - cluster size   |
# | **Multivariate** | x - correlation        |                    |

# %% [markdown]
# For each variable, we implemented a number of standard metrics, inspired by the climate extreme indices https://www.climdex.org/learn/indices/

# %%
tas_metrics = [warm_days, cold_days]
pr_metrics = [dry_days, wet_days, R10mm, R20mm]
tasmin_metrics = [tropical_nights, frost_days]
tasmax_metrics = [summer_days, icing_days]

# %% [markdown]
# In addition, the user can define new metrics in the following way:

# %%
R95p = AccumulativeThresholdMetric(name = '95th percentile \n precipitation', variable = 'pr', 
               threshold_value = np.quantile(np.ndarray.flatten(pr_obs), 0.95), threshold_type = 'higher')

R99p = AccumulativeThresholdMetric(name = '99th percentile \n precipitation', variable = 'pr', 
               threshold_value = np.quantile(np.ndarray.flatten(pr_obs), 0.99), threshold_type = 'higher')

# %% [markdown]
# ### Marginal Evaluation

# %% [markdown]
# We start by investigating the marginal bias of our chosen metrics and descriptive statistics. The user can start with a broader overview plot (see below) and then further investigate that have a particularly large bias, or a particularly large spread across locations, to investigate further.
#
# The plot below shows the distribution of marginal (location-wise) biases across locations. For the mean, this is for example calculated as follows:
#
# $$ Bias_{ij} = 100 * \frac{\bar{tas}_{obs, ij} - \bar{tas}_{cm, ij}}{\bar{tas}_{obs, ij}} $$

# %%
tas_marginal_bias_data = marginal.calculate_marginal_bias(metrics = tas_metrics,
                                                 obs_data = tas_obs_validate,
                                                 raw = tas_cm_validate, 
                                                 CDFT = tas_val_debiased_CDFT,
                                                 ISIMIP = tas_val_debiased_ISIMIP,
                                                 QM = tas_val_debiased_QM)

tas_marginal_bias_plot = marginal.plot_marginal_bias(variable = 'tas', bias_df = tas_marginal_bias_data)
plt.show()
# Out:
# /Users/fionaspuler/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/marginal.py:56: RuntimeWarning: invalid value encountered in true_divide
#   bias = 100 * (obs_metric - cm_metric) / obs_metric
# /Users/fionaspuler/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/marginal.py:56: RuntimeWarning: divide by zero encountered in true_divide
#   bias = 100 * (obs_metric - cm_metric) / obs_metric

# %%
pr_marginal_bias_data = marginal.calculate_marginal_bias(metrics = pr_metrics, obs_data = pr_obs_validate,
                                                 raw = pr_cm_validate, 
                                                 CDFT = pr_val_debiased_CDFT,
                                                 #ISIMIP = pr_val_debiased_ISIMIP,
                                                 QM = pr_val_debiased_QM)

pr_marginal_bias_data = pr_marginal_bias_data[~pr_marginal_bias_data["Metric"].isin(["5% qn"])]

pr_marginal_bias_plot = marginal.plot_marginal_bias(variable = 'pr', bias_df = pr_marginal_bias_data)
plt.show()
# Out:
# /Users/fionaspuler/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/marginal.py:56: RuntimeWarning: divide by zero encountered in true_divide
#   bias = 100 * (obs_metric - cm_metric) / obs_metric

# %%
tasmax_marginal_bias_data = marginal.calculate_marginal_bias(metrics = tasmax_metrics,
                                                 obs_data = tasmax_obs_validate,
                                                 raw = tasmax_cm_validate, 
                                                 ISIMIP = tasmax_val_debiased_ISIMIP)

tasmax_marginal_bias_plot = marginal.plot_marginal_bias(variable = 'tasmax', bias_df = tasmax_marginal_bias_data)
plt.show()

# %%
tasmin_marginal_bias_data = marginal.calculate_marginal_bias(metrics = tasmin_metrics,
                                                 obs_data = tasmin_obs_validate,
                                                 raw = tasmin_cm_validate, 
                                                 ISIMIP = tasmin_val_debiased_ISIMIP)

tasmax_marginal_bias_plot = marginal.plot_marginal_bias(variable = 'tasmin', bias_df = tasmin_marginal_bias_data)
plt.show()

# %% [markdown]
# **Conclusion**: TODO - write this when working with the actual testing data we want to show

# %% [markdown]
# **Spatial distribution of marginal biases**
#
# The shape of the distribution in the violinplot above already gives an indication of whether the bias is especially large over certain areas. The following plot explicitely shows the spacial distribution of biases. Particularly high biases in a certain region could point to deficiencies in the underlying climate model (for example, there could be a mountain range over which the climate model performs particularly badly, or other land-atmosphere interactions that are not captured).
#
# The plot below shows exactly the same data as the plot above, just the user chooses one descriptive statistic or threshold metric of which she wants to investigate the spatial distribution of its bias further.

# %%
tas_bias_map_mean = marginal.plot_bias_spatial(variable = 'tas', metric = 'Mean', bias_df = tas_marginal_bias_data)

# %%
pr_bias_map_mean = marginal.plot_bias_spatial(variable = 'pr', metric = 'Mean', bias_df = pr_marginal_bias_data)

# %%
tasmin_bias_map_mean = marginal.plot_bias_spatial(variable = 'tasmin', metric = 'Frost days \n  (tasmin<0°C)', bias_df = tasmin_marginal_bias_data)

# %%
pr_bias_map_mean = marginal.plot_bias_spatial(variable = 'pr', metric = 'Extremely wet days \n (> 20 mm/day)', bias_df = pr_marginal_bias_data)

# %% [markdown]
# ### Spatial, temporal and spatiotemporal properties

# %%
dry_spell_length = dry_days.calculate_spell_length(minimum_length = 4, obs = pr_obs_validate,
                                   raw = pr_cm_validate, QM = pr_val_debiased_QM,
                                   #ISIMIP = pr_val_debiased_ISIMIP, 
                                   CDFT = pr_val_debiased_CDFT)
dry_spell_length
# Out:
#       Correction Method                    Metric  Spell length
# 0                   obs  Dry days \n (< 1 mm/day)             5
# 1                   obs  Dry days \n (< 1 mm/day)             5
# 2                   obs  Dry days \n (< 1 mm/day)            12
# 3                   obs  Dry days \n (< 1 mm/day)             8
# 4                   obs  Dry days \n (< 1 mm/day)             5
# ...                 ...                       ...           ...
# 25129              CDFT  Dry days \n (< 1 mm/day)             7
# 25130              CDFT  Dry days \n (< 1 mm/day)             5
# 25131              CDFT  Dry days \n (< 1 mm/day)             9
# 25132              CDFT  Dry days \n (< 1 mm/day)            14
# 25133              CDFT  Dry days \n (< 1 mm/day)            12
#
# [97534 rows x 3 columns]

# %%
dry_days.violinplots_clusters(minimum_length = 4, obs = pr_obs_validate,
                                   raw = pr_cm_validate, QM = pr_val_debiased_QM,
                                   #ISIMIP = pr_val_debiased_ISIMIP, 
                                   CDFT = pr_val_debiased_CDFT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 dry_days.violinplots_clusters(minimum_length = 4, obs = pr_obs_validate,
#       2                                    raw = pr_cm_validate, QM = pr_val_debiased_QM,
#       3                                    #ISIMIP = pr_val_debiased_ISIMIP,
#       4                                    CDFT = pr_val_debiased_CDFT)
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/metrics.py:346, in ThresholdMetric.violinplots_clusters(self, minimum_length, **climate_data)
#     342 spatiotemporal_data = self.calculate_spatiotemporal_clusters(**climate_data)
#     344 fig, ax = plt.subplots(1, 3, figsize=(16, 6))
# --> 346 seaborn.violinplot(
#     347     ax=ax[0],
#     348     data=temporal_data,
#     349     x="Metric",
#     350     y="Spell length (days)",
#     351     palette="colorblind",
#     352     hue="Correction Method",
#     353 )
#     354 ax[0].set_title("Spell length (days)")
#     356 seaborn.violinplot(
#     357     ax=ax[1],
#     358     data=spatial_data,
#    (...)
#     362     hue="Correction Method",
#     363 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2400, in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2388 @_deprecate_positional_args
#    2389 def violinplot(
#    2390     *,
#    (...)
#    2397     ax=None, **kwargs,
#    2398 ):
# -> 2400     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2401                              bw, cut, scale, scale_hue, gridsize,
#    2402                              width, inner, split, dodge, orient, linewidth,
#    2403                              color, palette, saturation)
#    2405     if ax is None:
#    2406         ax = plt.gca()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:522, in _ViolinPlotter.__init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     517 def __init__(self, x, y, hue, data, order, hue_order,
#     518              bw, cut, scale, scale_hue, gridsize,
#     519              width, inner, split, dodge, orient, linewidth,
#     520              color, palette, saturation):
# --> 522     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     523     self.establish_colors(color, palette, saturation)
#     524     self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'Spell length (days)'

# %%
tas_rmsd_spatial = correlation.rmse_spatial_correlation_distribution(variable = 'tas', 
                                                         obs_data = tas_obs_validate, raw = tas_cm_future,
                                                         QM = tas_val_debiased_QM, ISIMIP = tas_val_debiased_ISIMIP,
                                                         CDFT = tas_val_debiased_CDFT)
tas_rmsd_spatial_plot = correlation.rmse_spatial_correlation_boxplot(variable = 'tas', dataset = tas_rmsd_spatial)
tas_rmsd_spatial_plot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 tas_rmsd_spatial = correlation.rmse_spatial_correlation_distribution(variable = 'tas',
#       2                                                          obs_data = tas_obs_validate, raw = tas_cm_future,
#       3                                                          QM = tas_val_debiased_QM, ISIMIP = tas_val_debiased_ISIMIP,
#       4                                                          CDFT = tas_val_debiased_CDFT)
#       5 tas_rmsd_spatial_plot = correlation.rmse_spatial_correlation_boxplot(variable = 'tas', dataset = tas_rmsd_spatial)
#       6 tas_rmsd_spatial_plot.show()
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/correlation.py:63, in rmse_spatial_correlation_distribution(variable, obs_data, **cm_data)
#      59         # calculate rmsd between two correlation matrices
#      60         rmsd = math.sqrt(sklearn.metrics.mean_squared_error(corr_matrix_obs, corr_matrix_cm))
#      62         rmsd_arrays.append(
# ---> 63             pd.DataFrame(data={"x": a, "y": b, "Correction Method": k, "RMSE spatial correlation": rmsd})
#      64     )
#      66 rmsd_data = pd.concat(rmsd_arrays)
#      67 rmsd_data["RMSE spatial correlation"] = pd.to_numeric(rmsd_data["RMSE spatial correlation"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:664, in _extract_index(data)
#     661         raise ValueError("Per-column arrays must each be 1-dimensional")
#     663 if not indexes and not raw_lengths:
# --> 664     raise ValueError("If using all scalar values, you must pass an index")
#     666 elif have_series:
#     667     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %% [markdown]
# ### Multivariate structure
#
# This section is currently in an experimental phase and will be expanded upon in the next releases. Nevertheless, we briefly guide you through the analysis that is currently possible.

# %%
multivariate.calculate_and_spatialplot_multivariate_correlation(variables = ['tas', 'pr'], obs = [tas_obs_validate, pr_obs_validate], 
                         raw = [tas_cm_validate, pr_cm_validate], CDFT = [tas_val_debiased_CDFT, pr_val_debiased_CDFT])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 multivariate.calculate_and_spatialplot_multivariate_correlation(variables = ['tas', 'pr'], obs = [tas_obs_validate, pr_obs_validate],
#       2                          raw = [tas_cm_validate, pr_cm_validate], CDFT = [tas_val_debiased_CDFT, pr_val_debiased_CDFT])
#
# File ~/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/multivariate.py:180, in calculate_and_spatialplot_multivariate_correlation(variables, manual_title, **kwargs)
#     177     i = i + 1
#     179 # set plot title
# --> 180 if variable in str_to_variable_class.keys():
#     181     plot_title = "Multivariate Correlation: {} and {}".format(
#     182                 map_variable_str_to_variable_class(variable[0]).name, map_variable_str_to_variable_class(variable[1]).name)
#     183 else:
#
# NameError: name 'variable' is not defined

# %%
frost_wet = multivariate.calculate_conditional_joint_threshold_exceedance(wet_days, frost_days,
                                                             obs = [pr_obs_validate, tasmin_obs_validate], 
                                                             raw = [pr_cm_validate, tasmin_cm_validate])

multivariate.plot_conditional_joint_threshold_exceedance(frost_wet)
# Out:
# [[       nan        nan        nan        nan        nan        nan
#          nan        nan        nan 0.14035088 0.12755102 0.5
#   0.33333333 0.14164306 0.16998469]
#  [       nan        nan        nan        nan        nan        nan
#   0.                nan 0.46153846 0.13926499 0.15447154 0.23976608
#   0.21014493 0.19103314 0.24545455]
#  [       nan        nan        nan        nan 0.05882353 0.171875
#   0.19047619 0.47058824 0.17647059 0.18298368 0.19494204 0.21276596
#   0.21997106 0.28774929 0.35275081]
#  [0.12315271 0.19895288 0.18348624 0.14977974 0.12190813 0.16615385
#   0.23809524 0.19414894 0.19101124 0.18577495 0.21062802 0.201
#   0.23424495 0.33617021 0.52287582]
#  [0.19629057 0.17848411 0.16425121 0.16591928 0.15939448 0.20549738
#   0.2134434  0.21236873 0.18394649 0.1882716  0.20582329 0.21119843
#   0.21267894 0.20113636 0.26039783]
#  [0.23892405 0.2659176  0.26057692 0.23427152 0.20113544 0.18418766
#   0.20812183 0.19092827 0.1922675  0.19959058 0.23007968 0.26819923
#   0.23805061 0.21223709 0.16683217]
#  [0.19085487 0.26636225 0.28148148 0.26344086 0.22629969 0.2219917
#   0.21570681 0.19938335 0.22427984 0.23038229 0.28754941 0.31870229
#   0.29769585 0.27058824 0.22506862]
#  [0.15246637 0.17083333 0.19701987 0.19583333 0.19451372 0.2038835
#   0.20721769 0.24084351 0.27995643 0.28118609 0.33498513 0.3478673
#   0.33824885 0.31559964 0.28305235]
#  [0.         0.11917098 0.13274336 0.15248227 0.17638266 0.20410959
#   0.20543807 0.26302414 0.29136691 0.30482456 0.31287726 0.35032437
#   0.34752389 0.34936709 0.34336859]
#  [       nan 0.35714286 0.09756098 0.17634409 0.16734694 0.19701493
#   0.19776119 0.24503311 0.29141104 0.31688312 0.36526946 0.36151079
#   0.37043189 0.38166144 0.37735849]
#  [0.5        0.16666667 0.1978022  0.20403587 0.16584158 0.22919334
#   0.23076923 0.26315789 0.30704225 0.33473684 0.37192982 0.37388193
#   0.3509342  0.37037037 0.3745401 ]
#  [0.45833333 0.28286853 0.26064736 0.24129353 0.26429342 0.27186147
#   0.26666667 0.28531469 0.31208791 0.29158111 0.28720238 0.29695886
#   0.31814483 0.3388931  0.35813275]
#  [0.42105263 0.35062893 0.27037618 0.33079057 0.33914729 0.32435982
#   0.2867182  0.26772908 0.244114   0.23624161 0.22736626 0.24396336
#   0.26579353 0.30936819 0.34004164]
#  [0.66666667 0.52016129 0.35914179 0.37178545 0.35297619 0.32879953
#   0.27306733 0.25752508 0.20500782 0.20123566 0.21781437 0.25459689
#   0.2812716  0.33069829 0.37483871]
#  [0.92592593 0.69306931 0.52649007 0.42647059 0.35603715 0.29627367
#   0.25609031 0.2677497  0.24197531 0.20093458 0.21220159 0.25769231
#   0.27629123 0.31234719 0.35162847]]
# [[       nan        nan        nan        nan        nan        nan
#          nan        nan        nan 0.         0.12903226 0.
#          nan 0.16901408 0.30672269]
#  [       nan        nan        nan        nan        nan        nan
#          nan        nan 0.16666667 0.128      0.21865889 0.55128205
#   0.42857143 0.84       0.41612903]
#  [0.57142857        nan        nan 1.         0.11764706 0.11627907
#   0.13973799 0.55952381 0.16908213 0.24727273 0.27687776 0.25314183
#   0.18543046 0.35714286 0.84375   ]
#  [0.21904762 0.1556196  0.15602837 0.47692308 0.14191419 0.13759214
#   0.14988814 0.18762887 0.2901354  0.40717629 0.40962289 0.27493261
#   0.19824561 0.14945652 0.4125    ]
#  [0.46868251 0.53757225 0.43726708 0.25059382 0.22057001 0.22924901
#   0.21802326 0.19966443 0.22648752 0.27746741 0.41310976 0.42983565
#   0.28822055 0.20151515 0.16283525]
#  [0.42682927 0.55993432 0.63194444 0.60557769 0.48487805 0.41182467
#   0.35855263 0.28791774 0.23564955 0.25328947 0.36298422 0.45294118
#   0.38148984 0.28226779 0.24684432]
#  [0.22685185 0.35820896 0.48046875 0.49492017 0.5        0.4616307
#   0.48079162 0.44770858 0.42335766 0.41472393 0.44183314 0.45568182
#   0.39348079 0.33212121 0.31683168]
#  [0.32307692 0.17910448 0.30445545 0.34186472 0.37397035 0.37400951
#   0.35267857 0.39863014 0.41604938 0.45776256 0.43857635 0.41339492
#   0.33888228 0.31559855 0.38973162]
#  [0.39655172 0.35114504 0.21568627 0.30570902 0.29304636 0.28382838
#   0.24369748 0.25955414 0.28029197 0.32317881 0.37257282 0.40837104
#   0.41747573 0.40062112 0.4112426 ]
#  [0.43478261 0.38333333 0.27325581 0.18895966 0.24727273 0.4815864
#   0.50872093 0.52830189 0.51378446 0.2767624  0.31402086 0.39440994
#   0.45028143 0.4839549  0.49064626]
#  [0.46153846 0.3373494  0.22727273 0.18739903 0.36779324 0.19305556
#   0.22285714 0.39622642 0.45727483 0.48964218 0.31982942 0.37788462
#   0.40266667 0.473466   0.50770479]
#  [0.51764706 0.44903581 0.39165819 0.43986543 0.38218623 0.31031543
#   0.24593301 0.23726977 0.40938511 0.44375963 0.4502994  0.47320526
#   0.35299003 0.36230707 0.38375796]
#  [0.46551724 0.4137931  0.56764296 0.56573957 0.453125   0.35286373
#   0.31164136 0.27863526 0.41501564 0.42291221 0.31980116 0.38657407
#   0.42910171 0.43364757 0.42241379]
#  [0.4375     0.53351955 0.40650407 0.49056604 0.4928527  0.43052109
#   0.36463023 0.37491385 0.47220047 0.44983819 0.3199703  0.38357143
#   0.42457338 0.45219124 0.46775244]
#  [0.75       0.53488372 0.55479452 0.62295082 0.37563086 0.43953186
#   0.44416719 0.41278709 0.39587242 0.3868472  0.47892977 0.34019934
#   0.35036018 0.36410587 0.36420137]]
# /Users/fionaspuler/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/multivariate.py:36: RuntimeWarning: invalid value encountered in true_divide
#   chi = np.einsum("ijk -> jk", cooccurrence) / np.einsum("ijk -> jk", metric2_instances)

# %% [markdown]
# ## Part 3: Evaluation of trend preservation
#
#
# This last section investigates whether the chosen bias correction method modify the trend in the climate model between the validation and the future period. The following steps are conducted in the calculation:
# - First, the trend in the chosen statistic (for example the mean) between the validation period and the future period in the *raw* climate model is calculated.
# - Then, the same calculation is performed for the debiased models of interest
# - Finally the percentage difference between these two trends is calculated.

# %%
tas_trend_bias_data = trend.calculate_future_trend_bias(variable = 'tas', 
                                                  raw_validate = tas_cm_validate, raw_future = tas_cm_future,
                                                        metrics = tas_metrics,
                                                  QM = [tas_val_debiased_QM, tas_fut_debiased_QM],
                                                  ISIMIP = [tas_val_debiased_ISIMIP, tas_fut_debiased_ISIMIP],
                                                  CDFT = [tas_val_debiased_CDFT, tas_fut_debiased_CDFT])

tas_trend_bias_data = tas_trend_bias_data[~tas_trend_bias_data["Metric"].isin(["Mean cold days (K)"])]


tas_trend_plot = trend.plot_future_trend_bias_boxplot(variable ='tas', bias_df = tas_trend_bias_data)
plt.show()
# Out:
# /Users/fionaspuler/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/trend.py:100: RuntimeWarning: divide by zero encountered in true_divide
#   trend_bias = 100 * (bc_trend - raw_trend) / raw_trend
# /Users/fionaspuler/Documents/GitHub/isimipy/notebooks/../PACKAGE_NAME/evaluate/trend.py:100: RuntimeWarning: invalid value encountered in true_divide
#   trend_bias = 100 * (bc_trend - raw_trend) / raw_trend

# %%
pr_trend_bias_data = trend.calculate_future_trend_bias(variable = 'pr',
                                                       raw_validate = pr_cm_validate, raw_future = pr_cm_future, 
                                                       metrics = pr_metrics,
                                                       QM = [pr_val_debiased_QM, pr_fut_debiased_QM],
                                                       #ISIMIP = [pr_val_debiased_ISIMIP, pr_fut_debiased_ISIMIP],
                                                       CDFT = [pr_val_debiased_CDFT, pr_fut_debiased_CDFT])

pr_trend_bias_data = pr_trend_bias_data[~pr_trend_bias_data["Metric"].isin(["5% qn"])]

pr_trend_plot = trend.plot_future_trend_bias_boxplot(variable ='pr', bias_df = pr_trend_bias_data)
plt.show()

# %% [markdown]
# **Conclusion**: TO-DO when working with final data

# %% [markdown]
# ## Conclusion
#
# To-do, write when working with actual data that we want to show

# %% [markdown]
# ## References

# %% [markdown]
# AIC: https://www.sciencedirect.com/topics/social-sciences/akaike-information-criterion
